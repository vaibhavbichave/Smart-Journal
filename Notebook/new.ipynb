# %%
import pandas as pd
df = pd.read_csv('../static/dataset/data_moods.csv')

# %%
df
# Out:
#                                             name  \
# 0                                           1999
# 1                                             23
# 2                                       9 Crimes
# 3                                 99 Luftballons
# 4    A Boy Brushed Red Living In Black And White
# ..                                           ...
# 681                                  windcatcher
# 682              yellow is the color of her eyes
# 683                           you broke me first
# 684                          you were good to me
# 685                                         æfre
#
#                                album          artist                      id  \
# 0                               1999          Prince  2H7PHVdQ3mXqEHXcvclTB0
# 1                                 23  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP
# 2                                  9     Damien Rice  5GZEeowhvSieFDiR8fQ2im
# ...

# %%
df1 = df[df.mood=='Happy']

# %%
x
# Out:
#                                                  name  \
# 0                                                1999
# 3                                      99 Luftballons
# 7   A Little Less Conversation - JXL Radio Edit Remix
# 14                                             Africa
# 25  All or Nothing (feat. Axel Ehnström) - Deluxe Mix
# 33                                             Anthem
#
#                               album            artist                      id  \
# 0                              1999            Prince  2H7PHVdQ3mXqEHXcvclTB0
# 3                    99 Luftballons              Nena  6HA97v4wEGQ5TUClRM0XLc
# 7   Elvis 75 - Good Rockin' Tonight     Elvis Presley  4l2hnfUx0esSbITQa7iJt0
# 14                          Toto IV              TOTO  2374M0fQpWi3dLnB54qaLX
# 25            Less is More (Deluxe)  Lost Frequencies  15bAMg00o4VdWmQrlkbfG3
# 33                           Anthem               EDX  1SSAvErVyid5OXzmtGZKkg
#
# ...
